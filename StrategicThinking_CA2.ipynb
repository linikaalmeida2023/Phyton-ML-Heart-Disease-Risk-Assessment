# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Heart-Diseases" data-toc-modified-id="Heart-Diseases-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Heart Diseases</a></span></li><li><span><a href="#Defining-the-problem-statement:" data-toc-modified-id="Defining-the-problem-statement:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Defining the problem statement:</a></span></li><li><span><a href="#Loading-the-data-and-Importing-Libraries" data-toc-modified-id="Loading-the-data-and-Importing-Libraries-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Loading the data and Importing Libraries</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Data-Visualization" data-toc-modified-id="Data-Visualization-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Data Visualization</a></span></li><li><span><a href="#Numerical-data" data-toc-modified-id="Numerical-data-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Numerical data</a></span></li><li><span><a href="#Categorical-data" data-toc-modified-id="Categorical-data-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Categorical data</a></span></li></ul></li><li><span><a href="#Data-Preparation" data-toc-modified-id="Data-Preparation-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Data Preparation</a></span><ul class="toc-item"><li><span><a href="#Labels-in-categorical-features" data-toc-modified-id="Labels-in-categorical-features-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Labels in categorical features</a></span></li><li><span><a href="#Feature-Selection" data-toc-modified-id="Feature-Selection-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Feature Selection</a></span></li></ul></li><li><span><a href="#TRAINING-DATA-AND-MACHINE-LEARNING-MODELS" data-toc-modified-id="TRAINING-DATA-AND-MACHINE-LEARNING-MODELS-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>TRAINING DATA AND MACHINE LEARNING MODELS</a></span><ul class="toc-item"><li><span><a href="#Linear-Discriminant-Analysis" data-toc-modified-id="Linear-Discriminant-Analysis-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Linear Discriminant Analysis</a></span></li><li><span><a href="#Model-Tuning-for-balancing-the-sample-by-Random-Under-Sampling" data-toc-modified-id="Model-Tuning-for-balancing-the-sample-by-Random-Under-Sampling-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Model Tuning for balancing the sample by Random Under Sampling</a></span></li><li><span><a href="#Training-Models" data-toc-modified-id="Training-Models-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Training Models</a></span></li><li><span><a href="#Linear-discriminant-analysis-(LDA)" data-toc-modified-id="Linear-discriminant-analysis-(LDA)-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Linear discriminant analysis (LDA)</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Logistic Regression</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Heart Diseases
# What factors influence the risk of having a heart attack?
#
# Scenario:
#
# We obtained medical data collected from a particular group of individuals who may or may not be at risk of experiencing a heart stroke.
#
# Data Dictionary
#
#     Gender: The gender of the patient
#     Age: The age of the patient
#     Education: The studies of the patient
#     currentSmoker: The patient is a current smoker? 0 = No / 1 = Yes
#     cigsPerDay: Quantity of cigarretes that the patient smokes each day.
#     BPMeds: The patient use blood pressure medication? 0 = No / 1 = Yes
#     prevalentStroke: The patient had a stroke recently? 0 = No / 1 = Yes
#     prevalentHyp: The patient had hypertension problems recently? 0 = No / 1 = Yes
#     diabetes: The patient have diabetes? 0 = No / 1 = Yes
#     totChol: Total of cholesterol of the patient
#     sysBP: Systolic blood pressure of the patient.
#     diaBP: Diastolic blood pressure of the patient
#     BMI: Body mass index of the patient
#     heartRate: Heart rate of the patient
#     glucose: Glucose of patient
#     Heart_stroke: The patient will have a heart_stroke? 0 = No / 1 = Yes

# %% [markdown]
# <a id='0'></a>
# # Defining the problem statement:
#
# Create a Predictive model which can tell if a person will have a heart disease.
#
# Target Variable: heart_stroke
# Predictors: age, sex, currentSmoker, cigsPerDay, etc.
#
# heart_stroke=0 The patient will not have a heart disease.
# heart_stroke=1 The patient will have a heart disease.

# %% [markdown]
# <a id='1'></a>
# # Loading the data and Importing Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from scipy.stats import f_oneway

#https://github.com/parrt/dtreeviz/blob/master/notebooks/dtreeviz_sklearn_visualisations.ipynb

import dtreeviz
from yellowbrick.model_selection import FeatureImportances
from sklearn import tree
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import make_scorer, f1_score

#Libraries for Saving the Model
from pickle import dump
from pickle import load

from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt
sns.set() 
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV

from sklearn.model_selection import train_test_split 
import numpy as np
from sklearn.decomposition import PCA

from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv("heart_disease.csv")

# %% [markdown]
# <a id='2'></a>
# #  Exploratory Data Analysis

# %%
df.shape
# Out:
# (4238, 16)

# %%
df.head(100)
# Out:
#     Gender  age      education  currentSmoker  cigsPerDay  BPMeds  \
# 0     Male   39   postgraduate              0         0.0     0.0
# 1   Female   46  primaryschool              0         0.0     0.0
# 2     Male   48     uneducated              1        20.0     0.0
# 3   Female   61       graduate              1        30.0     0.0
# 4   Female   46       graduate              1        23.0     0.0
# ..     ...  ...            ...            ...         ...     ...
# 95  Female   65       graduate              0         0.0     0.0
# 96  Female   63   postgraduate              1        20.0     0.0
# 97  Female   40  primaryschool              0         0.0     0.0
# 98  Female   56     uneducated              0         0.0     0.0
# 99  Female   56     uneducated              1        15.0     0.0
#
#    prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0               no             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           4238 non-null   object
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   object
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   object
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  Heart_ stroke    4238 non-null   object
# ...

# %%
df.dtypes
# Out:
# Gender              object
# age                  int64
# education           object
# currentSmoker        int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke     object
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# Heart_ stroke       object
# dtype: object

# %% [markdown]
# As shown in the results above, the data has a mix of float, int and object.

# %%
df.describe(include='all')
# Out:
#         Gender          age   education  currentSmoker   cigsPerDay  \
# count     4238  4238.000000        4133    4238.000000  4209.000000
# unique       2          NaN           4            NaN          NaN
# top     Female          NaN  uneducated            NaN          NaN
# freq      2419          NaN        1720            NaN          NaN
# mean       NaN    49.584946         NaN       0.494101     9.003089
# std        NaN     8.572160         NaN       0.500024    11.920094
# min        NaN    32.000000         NaN       0.000000     0.000000
# 25%        NaN    42.000000         NaN       0.000000     0.000000
# 50%        NaN    49.000000         NaN       0.000000     0.000000
# 75%        NaN    56.000000         NaN       1.000000    20.000000
# max        NaN    70.000000         NaN       1.000000    70.000000
#
#              BPMeds prevalentStroke  prevalentHyp     diabetes      totChol  \
# ...

# %% [markdown]
# Using this methods: head() / info() / describe() will help us have some summarized information of the data as well ass some of the rows and the statistical details like the mean, mode and median of each column.
#
#
# Using nunique() method we will find the unique values of each column. This can help us to understand which column is categorical and which one is continuos.

# %% [markdown]
# What is Categorical Data?
# - Categorical data is statistical information that is presented according to its division into certain groups. In this model,     values are sorted into predefined categories according to the design of the analysts. Grouping data points into categories       in this way can be useful depending on the goals of the research, but it’s only one of many ways to orient statistical information.
#
# What is Continuous Data?
# - Continuous data describes information that can take virtually any value. This includes things like height, weight or any kind of numerical measurement. The type of information that produces continuous data is often likely to change with time as well.

# %% [markdown]
#     Gender: Selected. Categorical
#     Age: Selected. Continuous
#     Education: Categorical. Rejected. Your education will not help you prevent a heart disease.
#     currentSmoker: Selected. Categorical
#     cigsPerDay: Selected. Continuous
#     BPMeds: Selected. Categorical.
#     prevalentStroke: Selected. Categorical
#     prevalentHyp: Selected. Categorical
#     diabetes: Selected. Categorical
#     totChol: Selected. Continuous
#     sysBP: Selected. Continuous
#     diaBP: Selected. Continuous
#     BMI: Selected. Continuous
#     heartRate: Selected. Continuous
#     glucose: Selected. Continuous
#     Heart_ stroke: Selected. Categorical. This is our target variable.

# %%
df.nunique()
# Out:
# Gender                2
# age                  39
# education             4
# currentSmoker         2
# cigsPerDay           33
# BPMeds                2
# prevalentStroke       2
# prevalentHyp          2
# diabetes              2
# totChol             248
# sysBP               234
# diaBP               146
# BMI                1363
# heartRate            73
# glucose             143
# Heart_ stroke         2
# dtype: int64

# %% [markdown]
# Knowing our unique values of each column, I will proceed by identify as categorical column the ones that have less than 10 unique values. The other ones I will identify them by continuous. In this step, we will decide as well which column is useless for our analysis and then remove it from our dataset.

# %% [markdown]
# <a id='2.2'></a>
# ##  Data Visualization

# %% [markdown]
# Let us check the number of Heart stroke vs. non-Heart stroke cases in the data set.

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':9,'ytick.labelsize':9, 'figure.autolayout':True})
plt.subplots(figsize=(7,4))

plt.subplot(1,2,1)
plt.title('Heart Stroke Cases (in Units)', fontdict={'fontsize':9})
ax = sns.countplot(x="Heart_ stroke", data=df, order=df['Heart_ stroke'].value_counts().index)

for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.30, p.get_height()+8))

plt.subplot(1,2,2)
plt.title('Heart Stroke Cases (in %)', fontdict={'fontsize':9})
df['Heart_ stroke'].value_counts().plot(kind='pie', legend=None, ylabel='', autopct='%1.1f%%')

plt.show()

# %% [markdown]
# Looking at our data, we can see that the number of patients which will not have a heart disease is way greater than the patients who will have one. This is okay, we can still continue to analyze our data BUT we will add some synthetic data in our training to balance our target variable.

# %% [markdown]
# Before replacing null values, I will check my dataset plot to see how it looks. This will help us determine which option to choose from mode, median and mean to replace our nulls. I'm applying this only to my numeric data.

# %%
plt.hist(df.select_dtypes(include='number'))

# Add axis labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %% [markdown]
# ## Numerical data
# Looking at the column Age.

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':14,'ytick.labelsize':14, 'figure.autolayout':True})
plt.subplots(figsize=(16,22))

plt.subplot(8,2,1)
plt.title('Age of the Individual : Histogram', fontdict={'fontsize':15})
sns.distplot(df.age, kde_kws={'linewidth':2,'color':'r'});

# %% [markdown]
# Here we can tell that heart strokes happen more to people that are between 40 and 50 years old.

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':14,'ytick.labelsize':14, 'figure.autolayout':True})
plt.subplots(figsize=(16,22))

plt.subplot(8,2,1)
plt.title('Cigarettes / Day: Histogram', fontdict={'fontsize':15})
sns.distplot(df.cigsPerDay, kde_kws={'linewidth':2,'color':'r'});

# %% [markdown]
# In this plot, we can see that there are some outliers. I consider that is possible that some people smokes 40 cigarretes or more by day, so I dont see why we should think that this is some finger mistake. I will not remove them.

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':14,'ytick.labelsize':14, 'figure.autolayout':True})
plt.subplots(figsize=(16,22))

plt.subplot(8,2,1)
plt.title('Total Cholesterol Levels: Histogram', fontdict={'fontsize':15})
sns.distplot(df.totChol, kde_kws={'linewidth':2,'color':'r'});

# %% [markdown]
# We see that totChol column have outliers as well. I find it possible for a person to have that much of cholesterol so I will not delete them. We can see that this column have a normal distribution. Most of the patients have between 200 and 300 of cholesterol.

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':14,'ytick.labelsize':14, 'figure.autolayout':True})
plt.subplots(figsize=(16,22))

plt.subplot(8,2,1)
plt.title('Systolic BP : Histogram', fontdict={'fontsize':15})
sns.distplot(df.sysBP, kde_kws={'linewidth':2,'color':'r'});

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':14,'ytick.labelsize':14, 'figure.autolayout':True})
plt.subplots(figsize=(16,22))

plt.subplot(8,2,1)
plt.title('Diastolic BP : Histogram', fontdict={'fontsize':15})
sns.distplot(df.diaBP, kde_kws={'linewidth':2,'color':'r'});

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':14,'ytick.labelsize':14, 'figure.autolayout':True})
plt.subplots(figsize=(16,22))

plt.subplot(8,2,1)
plt.title('BMI : Histogram', fontdict={'fontsize':15})
sns.distplot(df.BMI, kde_kws={'linewidth':2,'color':'r'});

# %% [markdown]
# BMI also have a normal distribution.

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':14,'ytick.labelsize':14, 'figure.autolayout':True})
plt.subplots(figsize=(16,22))

plt.subplot(8,2,1)
plt.title('Heart Rate : Histogram', fontdict={'fontsize':15})
sns.distplot(df.heartRate, kde_kws={'linewidth':2,'color':'r'});

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':14,'ytick.labelsize':14, 'figure.autolayout':True})
plt.subplots(figsize=(16,22))

plt.subplot(8,2,1)
plt.title('Glucose : Histogram', fontdict={'fontsize':15})
sns.distplot(df.glucose, kde_kws={'linewidth':2,'color':'r'});

# %% [markdown]
# Glucose have also a normal distribution.
#
# The normal distribution is a continuous probability distribution that is symmetrical around its mean, most of the observations cluster around the central peak, and the probabilities for values further away from the mean taper off equally in both directions. Extreme values in both tails of the distribution are similarly unlikely. While the normal distribution is symmetrical, not all symmetrical distributions are normal.

# %% [markdown]
# ## Categorical data
# Looking at the categorical data.

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':16,'ytick.labelsize':16, 'figure.autolayout':True})
plt.subplots(figsize=(16,26))

plt.subplot(6,3,1)
plt.title('Gender Vs Heart_ stroke', fontdict={'fontsize':15})
ax = sns.countplot(x='Gender', hue='Heart_ stroke', data=df);
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+8))

# %% [markdown]
# We can see that there are more females patients in this dataset. Even though there are more females, we have more males having more heart strokes.

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':16,'ytick.labelsize':16, 'figure.autolayout':True})
plt.subplots(figsize=(16,26))

plt.subplot(6,3,1)
plt.title('currentSmoker Vs Heart_ stroke', fontdict={'fontsize':15})
ax = sns.countplot(x='currentSmoker', hue='Heart_ stroke', data=df)
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+8))

# %% [markdown]
# We can see that there are more non smokers patients. It's funny to see that the difference between smokers and non smokers in having a heart stroke is slightly different. One would assume that smoking will make you more vulnerable

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':16,'ytick.labelsize':16, 'figure.autolayout':True})
plt.subplots(figsize=(16,26))

plt.subplot(6,3,1)
plt.title('diabetes Vs Heart_ stroke', fontdict={'fontsize':15})
ax = sns.countplot(x='diabetes', hue='Heart_ stroke', data=df)
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+8))

# %% [markdown]
# We can see that almost all of the patients that have diabetes are more likeable to get a heart stroke.

# %%
sns.set(rc={'axes.facecolor':'none','axes.grid':False,'xtick.labelsize':16,'ytick.labelsize':16, 'figure.autolayout':True})
plt.subplots(figsize=(16,26))

plt.subplot(6,3,1)
plt.title('prevalentHyp Vs Heart_ stroke', fontdict={'fontsize':15})
ax = sns.countplot(x='prevalentHyp', hue='Heart_ stroke', data=df)
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.10, p.get_height()+8))

# %% [markdown]
# The number of patients without hypertension are greater, but it seems that having hypertension will make you have a heart stroke. Is similar to diabetes vs heart stroke.

# %% [markdown]
# <a id='3'></a>
# # Data Preparation

# %% [markdown]
# Taking the time of ready the csv file, we found that they were some values with 'NA', this means we need to replace those values with NaN values.

# %%
missing_value_formats = ["NA"]
df = pd.read_csv("heart_disease.csv", na_values = missing_value_formats)

# %%
print('Number of records (rows) in the dataset are:', df.shape[0])
print('Number of features (columns) in the dataset are:', df.shape[1])
print('Number of values in the dataset are:', df.count().sum())
print('Number missing values in the dataset are:', sum(df.isna().sum()))
# Out:
# Number of records (rows) in the dataset are: 4238
# Number of features (columns) in the dataset are: 16
# Number of values in the dataset are: 67163
# Number missing values in the dataset are: 645

# %% [markdown]
# According to our analsysis so far, it seems our dataset contains some null values. We will proceed to determine how many null values are by column

# %%
pd.isna(df).sum()[pd.isna(df).sum() > 0]
# Out:
# education     105
# cigsPerDay     29
# BPMeds         53
# totChol        50
# BMI            19
# heartRate       1
# glucose       388
# dtype: int64

# %% [markdown]
# This visualization show me the that the data in our dataset have a skewness. Knowing this, I will proceed by filling the null values of my numerical values with the median.
#
# With my categorical columns, I will proceed to fill the nulls with the mode of each column.

# %%
#Replacing null values of our numerical data with the median 
df.glucose.fillna(df.glucose.median(),inplace = True)
df.cigsPerDay.fillna(df.cigsPerDay.median(),inplace = True)
df.totChol.fillna(df.totChol.median(),inplace = True)
df.BMI.fillna(df.BMI.median(),inplace = True)
df.heartRate.fillna(df.heartRate.median(),inplace = True)
df.BPMeds.fillna(df.BPMeds.median(),inplace = True)
df['education'].fillna('unknown', inplace=True)

#Replacing null values of our object data with the mode
df.prevalentStroke = df.prevalentStroke.fillna(df.prevalentStroke.mode().iloc[0])

# %% [markdown]
# Now that I have replaced the nulls, I will check if there are still nulls values left on the dataset.

# %%
pd.isna(df).sum()[pd.isna(df).sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## Labels in categorical features

# %%
## Let's check the labels in categorical features

for col in df.columns:
    if df[col].dtype=='object':
        print()
        print(col)
        print(df[col].unique())
# Out:
# Gender
# ['Male' 'Female']
#
# education
# ['postgraduate' 'primaryschool' 'uneducated' 'graduate' 'unknown']
#
# prevalentStroke
# ['no' 'yes']
#
# Heart_ stroke
# ['No' 'yes']

# %% [markdown]
# We going to separate our categorical and numercial columns. I will do this proccess so I can be able transform the categorical data to labeled data and then concat it with my numerical columns.

# %%
categoricalColumns = df.select_dtypes(exclude=["int", "float"])

numericalColumns = df.select_dtypes(include=['int', 'float'])

# %%
categoricalColumns
# Out:
#       Gender      education prevalentStroke Heart_ stroke
# 0       Male   postgraduate              no            No
# 1     Female  primaryschool              no            No
# 2       Male     uneducated              no            No
# 3     Female       graduate              no           yes
# 4     Female       graduate              no            No
# ...      ...            ...             ...           ...
# 4233    Male     uneducated              no           yes
# 4234    Male       graduate              no            No
# 4235  Female  primaryschool              no            No
# 4236  Female     uneducated              no            No
# 4237  Female  primaryschool              no            No
#
# [4238 rows x 4 columns]

# %% [markdown]
# Time to label our categorical columns.

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder ()

for i in categoricalColumns:
    categoricalColumns[i] = LE.fit_transform(df[i])

# %%
categoricalColumns.head()
# Out:
#    Gender  education  prevalentStroke  Heart_ stroke
# 0       1          1                0              0
# 1       0          2                0              0
# 2       1          3                0              0
# 3       0          0                0              1
# 4       0          0                0              0

# %%
completeDataset = pd.concat([numericalColumns, categoricalColumns], axis=1)
completeDataset.head(5)
# Out:
#    age  currentSmoker  cigsPerDay  BPMeds  prevalentHyp  diabetes  totChol  \
# 0   39              0         0.0     0.0             0         0    195.0
# 1   46              0         0.0     0.0             0         0    250.0
# 2   48              1        20.0     0.0             0         0    245.0
# 3   61              1        30.0     0.0             1         0    225.0
# 4   46              1        23.0     0.0             0         0    285.0
#
#    sysBP  diaBP    BMI  heartRate  glucose  Gender  education  \
# 0  106.0   70.0  26.97       80.0     77.0       1          1
# 1  121.0   81.0  28.73       95.0     76.0       0          2
# 2  127.5   80.0  25.34       75.0     70.0       1          3
# 3  150.0   95.0  28.58       65.0    103.0       0          0
# 4  130.0   84.0  23.10       85.0     85.0       0          0
#
#    prevalentStroke  Heart_ stroke
# 0                0              0
# 1                0              0
# 2                0              0
# ...

# %% [markdown]
# Now I will check the correlations of my dataset.

# %%
correlation = completeDataset.corr()
correlation['Heart_ stroke'].sort_values(ascending=False)
# Out:
# Heart_ stroke      1.000000
# age                0.225256
# sysBP              0.216429
# prevalentHyp       0.177603
# diaBP              0.145299
# glucose            0.121277
# diabetes           0.097317
# Gender             0.088428
# BPMeds             0.086417
# totChol            0.081566
# BMI                0.074217
# prevalentStroke    0.061810
# cigsPerDay         0.058859
# education          0.056339
# heartRate          0.022857
# currentSmoker      0.019456
# Name: Heart_ stroke, dtype: float64

# %%
# correlation betweem the features
plt.figure(figsize=(17,6))
sns.heatmap((correlation), annot=True, cmap='coolwarm');

# %% [markdown]
# We can observe that age, sysBP, prevalentHyp,diaBP, and glucose are the features that have the most correlation in haveing a heart stroke.

# %% [markdown]
# <a id='3.2'></a>
# ## Feature Selection

# %%
from sklearn.feature_selection import SelectKBest

bestfeatures = SelectKBest(k=10)
bestfeatures
Y= completeDataset["Heart_ stroke"]
X = completeDataset.loc[:, completeDataset.columns != 'Heart_ stroke']
fit = bestfeatures.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
#            Specs       Score
# 0            age  226.424830
# 7          sysBP  208.171803
# 4   prevalentHyp  137.966856
# 8          diaBP   91.358454
# 11       glucose   63.234023
# 5       diabetes   40.500615
# 12        Gender   33.384171
# 3         BPMeds   31.872136
# 6        totChol   28.370713
# 9            BMI   23.461568

# %%
# Checking the top 10 features
top_10_features = featureScores.nlargest(10, 'Score')

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Score', y='Specs', data=top_10_features, palette="viridis")
plt.title('Top 10 Important Features')
plt.xlabel('Score')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# <a id='4'></a>
# # TRAINING DATA AND MACHINE LEARNING MODELS

# %%
# Define the dependent variable 'Heart _stroke' and independent variables
# split out validation dataset for the end

y = completeDataset["Heart_ stroke"]
#X = completeDataset.loc[:, completeDataset.columns != 'Heart_ stroke']
X = completeDataset.loc[:, ["age", "sysBP", "prevalentHyp", "diaBP", "glucose", 'diabetes','Gender','BPMeds', 'totChol','BMI']]

# %%
#train and test

X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.3, random_state=42)
scoring = 'accuracy'

# %%
# spot check some basic Classification algorithms
#Given Data is huge, some of the slower classification algorithms are commented
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
# #Neural Network
models.append(('NN', MLPClassifier()))
# # #Ensable Models 
# # Boosting methods
models.append(('AB', AdaBoostClassifier()))
models.append(('GBM', GradientBoostingClassifier()))
# # Bagging methods
models.append(('RF', RandomForestClassifier()))
models.append(('ET', ExtraTreesClassifier()))

# %%
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=7, shuffle=True, random_state=42)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, np.nanmean(cv_results), np.nanstd(cv_results))
    print(msg)
# Out:
# LR: 0.847272 (0.011439)
# LDA: 0.846595 (0.012484)
# KNN: 0.833450 (0.013358)
# CART: 0.747818 (0.017137)
# NB: 0.817598 (0.005050)
# SVM: 0.847945 (0.014738)
# NN: 0.844574 (0.012929)
# AB: 0.841874 (0.016610)
# GBM: 0.841197 (0.019109)
# RF: 0.841538 (0.015980)
# ET: 0.842550 (0.010209)

# %% [markdown]
# Given the LR and LDA has the best recall out of all the models, it is used to ealuate the test set

# %% [markdown]
# ## Linear Discriminant Analysis

# %%
# Build model
model = LinearDiscriminantAnalysis()
model.fit(X_train, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
# estimate accuracy on validation set
#rescaledValidationX = scaler.transform(X_validation)
rescaledValidationX = X_validation
predictions = model.predict(rescaledValidationX)
print(accuracy_score(y_validation, predictions))
print(confusion_matrix(y_validation, predictions))
print(classification_report(y_validation, predictions))
# Out:
# 0.8522012578616353
# [[1066   18]
#  [ 170   18]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      1084
#            1       0.50      0.10      0.16       188
#
#     accuracy                           0.85      1272
#    macro avg       0.68      0.54      0.54      1272
# weighted avg       0.81      0.85      0.81      1272

# %%
df_cm = pd.DataFrame(confusion_matrix(y_validation, predictions), 
                     columns=np.unique(y_validation), 
                     index = np.unique(y_validation))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
sns.heatmap(df_cm, cmap='plasma_r', annot=True,annot_kws={"size": 16}, fmt='g');
plt.title('Confusin Matrix', fontsize=14);

# %% [markdown]
# <a id='5.2'></a>
# ## Model Tuning for balancing the sample by Random Under Sampling

# %%
df = pd.concat([X_train, y_train], axis=1)
# who had Heart stroke 644 vs. who had not 3594.
Heart_stroke_yes = df.loc[df['Heart_ stroke'] == 1]
Heart_stroke_No = df.loc[df['Heart_ stroke'] == 0][:Heart_stroke_yes.shape[0]]

normal_distributed_df = pd.concat([Heart_stroke_yes, Heart_stroke_No])

# Shuffle dataframe rows
df_new = normal_distributed_df.sample(frac=1, random_state=42)
# split out validation dataset for the end
Y_train_new = df_new['Heart_ stroke']
X_train_new = df_new.loc[:, df.columns != 'Heart_ stroke']

completeDataset.head()
# Out:
#    age  currentSmoker  cigsPerDay  BPMeds  prevalentHyp  diabetes  totChol  \
# 0   39              0         0.0     0.0             0         0    195.0
# 1   46              0         0.0     0.0             0         0    250.0
# 2   48              1        20.0     0.0             0         0    245.0
# 3   61              1        30.0     0.0             1         0    225.0
# 4   46              1        23.0     0.0             0         0    285.0
#
#    sysBP  diaBP    BMI  heartRate  glucose  Gender  education  \
# 0  106.0   70.0  26.97       80.0     77.0       1          1
# 1  121.0   81.0  28.73       95.0     76.0       0          2
# 2  127.5   80.0  25.34       75.0     70.0       1          3
# 3  150.0   95.0  28.58       65.0    103.0       0          0
# 4  130.0   84.0  23.10       85.0     85.0       0          0
#
#    prevalentStroke  Heart_ stroke
# 0                0              0
# 1                0              0
# 2                0              0
# ...

# %%
df_new['Heart_ stroke'].unique()
# Out:
# array([0, 1])

# %%
print('Distribution of the Heart stroke in the subsample dataset')
print(df_new['Heart_ stroke'].value_counts() / len(df_new))
sns.countplot(x='Heart_ stroke', data=df_new)
plt.title('Equally Distributed Classes', fontsize=14);
plt.show();
# Out:
# Distribution of the Heart stroke in the subsample dataset
# 0    0.5
# 1    0.5
# Name: Heart_ stroke, dtype: float64

# %% [markdown]
# Now that we have our dataframe correctly balanced, we can go further with our analysis and data preprocessing.
#
# ## Training Models

# %%
scoring='accuracy'

# %%
# spot check the algorithms
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
#Neural Network
models.append(('NN', MLPClassifier()))
# #Ensable Models 
# Boosting methods
models.append(('AB', AdaBoostClassifier()))
models.append(('GBM', GradientBoostingClassifier()))
# Bagging methods
models.append(('RF', RandomForestClassifier()))
models.append(('ET', ExtraTreesClassifier()))

# %%
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=7, shuffle=True, random_state=42)
    cv_results = cross_val_score(model, X_train_new, Y_train_new,
                                 cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, np.nanmean(cv_results), 
                           np.nanstd(cv_results))
    print(msg)
# Out:
# LR: 0.648066 (0.058939)
# LDA: 0.657906 (0.045011)
# KNN: 0.588776 (0.041989)
# CART: 0.587736 (0.037732)
# NB: 0.598733 (0.032759)
# SVM: 0.620611 (0.050867)
# NN: 0.597609 (0.035291)
# AB: 0.622775 (0.032701)
# GBM: 0.637044 (0.036481)
# RF: 0.639233 (0.041692)
# ET: 0.627196 (0.019503)

# %%
# compare algorithms
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
fig.set_size_inches(8,4)
plt.show()

# %% [markdown]
# Given that LDA and LR are the best model out of all the models we going to proceed with them.
#
# ## Linear discriminant analysis (LDA)
#
# Tuning model using grid search is performed for LDA model by the appropriate solver, shrinkage methodo, Number of components to keep and Tolerance for convergence.

# %%
param_grid = {
    'solver': ['svd', 'lsqr', 'eigen'],  # the appropriate solver
    'shrinkage': ['auto', None],  # the appropriate shrinkage method
    'n_components': [None, 1, 2, 3],  # Number of components to keep
    'tol': [1e-4, 1e-3, 1e-2]  # Tolerance for convergence
}

model = LinearDiscriminantAnalysis()

grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(X_train_new, Y_train_new)

# Results GridSearchCV
print("Best Parameters: ", grid_result.best_params_)
print("Best Score: ", grid_result.best_score_)

# Detailed results for each combination of hyperparameters
results = grid_result.cv_results_
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"Mean Score: {mean_score:.4f}, Parameters: {params}")
# Out:
# Best Parameters:  {'n_components': None, 'shrinkage': 'auto', 'solver': 'lsqr', 'tol': 0.0001}
# Best Score:  0.6589967284623773
# Mean Score: nan, Parameters: {'n_components': None, 'shrinkage': 'auto', 'solver': 'svd', 'tol': 0.0001}
# Mean Score: nan, Parameters: {'n_components': None, 'shrinkage': 'auto', 'solver': 'svd', 'tol': 0.001}
# Mean Score: nan, Parameters: {'n_components': None, 'shrinkage': 'auto', 'solver': 'svd', 'tol': 0.01}
# Mean Score: 0.6590, Parameters: {'n_components': None, 'shrinkage': 'auto', 'solver': 'lsqr', 'tol': 0.0001}
# Mean Score: 0.6590, Parameters: {'n_components': None, 'shrinkage': 'auto', 'solver': 'lsqr', 'tol': 0.001}
# Mean Score: 0.6590, Parameters: {'n_components': None, 'shrinkage': 'auto', 'solver': 'lsqr', 'tol': 0.01}
# Mean Score: 0.6590, Parameters: {'n_components': None, 'shrinkage': 'auto', 'solver': 'eigen', 'tol': 0.0001}
# ...

# %%
# prepare model
model = LinearDiscriminantAnalysis(n_components=1, shrinkage=None, solver='lsqr', tol=0.0001)
model.fit(X_train_new, Y_train_new)
# Out:
# LinearDiscriminantAnalysis(n_components=1, solver='lsqr')

# %%
# estimate accuracy on Original validation set
predictions = model.predict(X_validation)  
print(accuracy_score(y_validation, predictions))
print(confusion_matrix(y_validation, predictions))
print(classification_report(y_validation, predictions))
# Out:
# 0.6556603773584906
# [[708 376]
#  [ 62 126]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.65      0.76      1084
#            1       0.25      0.67      0.37       188
#
#     accuracy                           0.66      1272
#    macro avg       0.59      0.66      0.56      1272
# weighted avg       0.82      0.66      0.70      1272

# %%
df_cm = pd.DataFrame(confusion_matrix(y_validation, predictions),
                     columns=np.unique(y_validation),
                     index=np.unique(y_validation))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
sns.heatmap(df_cm, cmap='cividis', annot=True, annot_kws={"size": 16}, fmt='g');
plt.title('Confusin Matrix', fontsize=14);

# %% [markdown]
# ## Logistic Regression

# %%
# Train a logistic regression model on the transformed data
lr = LogisticRegression()
lr.fit(X_train_new, Y_train_new,)
# Out:
# LogisticRegression()

# %%
# Evaluate the performance of the logistic regression model on the testing set
y_pred = lr.predict(X_train_new)
accuracy = accuracy_score(Y_train_new, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.6414473684210527

# %%
# estimate accuracy on Original validation set
lr_predictions = lr.predict(X_train_new)
print(accuracy_score(Y_train_new, y_pred))
print(confusion_matrix(Y_train_new, y_pred))
print(classification_report(Y_train_new, y_pred))
# Out:
# 0.6414473684210527
# [[302 154]
#  [173 283]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.66      0.65       456
#            1       0.65      0.62      0.63       456
#
#     accuracy                           0.64       912
#    macro avg       0.64      0.64      0.64       912
# weighted avg       0.64      0.64      0.64       912

# %%
df_cm = pd.DataFrame(confusion_matrix(Y_train_new, lr_predictions), 
                     columns=np.unique(Y_train_new), 
                     index = np.unique(Y_train_new))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
sns.heatmap(df_cm, cmap="Oranges", annot=True,annot_kws={"size": 16},fmt='g');
plt.title('Confusin Matrix', fontsize=14);

# %%
 # Choosing hypermeter
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  
    'penalty': ['l1', 'l2']  
}
# Model 
lr = LogisticRegression()

# Creating grid search
grid_search = GridSearchCV(lr, param_grid, cv=5, scoring=make_scorer(f1_score))

# Fit GridSearchCV
grid_search.fit(X_train_new, Y_train_new)

# Print the best Hypermeter 
print("The best Hypermeters:", grid_search.best_params_)

# Make predctions with using the best hypermeter
Y_pred = grid_search.best_estimator_.predict(X_validation)

# Evaluate model performance
f1 = f1_score(y_validation, Y_pred)
print("F1 Score in the data set:", f1)
# Out:
# The best Hypermeters: {'C': 0.001, 'penalty': 'l2'}
# F1 Score in the data set: 0.3428571428571429

# %%
# Train a logistic regression model on the transformed data
lr = LogisticRegression(C= 0.001, penalty= 'l2')
lr.fit(X_train_new, Y_train_new,)
# Out:
# LogisticRegression(C=0.001)

# %%
# Evaluate the performance of the logistic regression model on the testing set
y_pred = lr.predict(X_validation)
accuracy = accuracy_score(y_validation, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.6564465408805031

# %%
# estimate accuracy on Original validation set
print(confusion_matrix(y_validation, y_pred))
print(classification_report(y_validation, y_pred))
# Out:
# [[721 363]
#  [ 74 114]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.67      0.77      1084
#            1       0.24      0.61      0.34       188
#
#     accuracy                           0.66      1272
#    macro avg       0.57      0.64      0.56      1272
# weighted avg       0.81      0.66      0.70      1272

# %%
df_cm = pd.DataFrame(confusion_matrix(Y_train_new, lr_predictions), 
                     columns=np.unique(Y_train_new), 
                     index = np.unique(Y_train_new))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
sns.heatmap(df_cm, cmap='cool', annot=True,annot_kws={"size": 16},fmt='g');
plt.title('Confusin Matrix', fontsize=14);
